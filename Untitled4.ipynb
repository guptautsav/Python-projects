# %% [markdown]
# <a href="https://colab.research.google.com/github/guptautsav/Python-projects/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Customer Lifetime value analysis project

# %%
import pandas as pd
import plotly.graph_objects as go
import plotly.express as px
import plotly.io as pio
pio.templates.default = "plotly_white"

# %%
data = pd.read_csv("customer_acquisition_data.csv")

# %%
data
# Out:
#      customer_id           channel       cost  conversion_rate  revenue
# 0              1          referral   8.320327         0.123145     4199
# 1              2  paid advertising  30.450327         0.016341     3410
# 2              3   email marketing   5.246263         0.043822     3164
# 3              4      social media   9.546326         0.167592     1520
# 4              5          referral   8.320327         0.123145     2419
# ..           ...               ...        ...              ...      ...
# 795          796      social media   9.546326         0.167592     2813
# 796          797   email marketing   5.246263         0.043822     3439
# 797          798      social media   9.546326         0.167592     2101
# 798          799  paid advertising  30.450327         0.016341      813
# 799          800   email marketing   5.246263         0.043822     4820
#
# [800 rows x 5 columns]

# %% [markdown]
# #Visualizing the distribution of acquisition cost and revenue generated by the customer usig histogram.

# %%
fig = px.histogram(data, x="cost",nbins=20, title="Distribution of Acquisition Cost")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.histogram(data, x="revenue",nbins=20, title="Distribution of Acquisition Cost")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
cost_by_channel = data.groupby("channel")["cost"].mean().reset_index()
revenue_by_channel = data.groupby("channel")["revenue"].sum()

# %%
cost_by_channel
# Out:
#             channel       cost
# 0   email marketing   5.246263
# 1  paid advertising  30.450327
# 2          referral   8.320327
# 3      social media   9.546326

# %%
cost_by_channel = data.groupby("channel")["cost"].mean().reset_index()

fig = px.bar(cost_by_channel,
             x="channel", y="cost",
             title="Average Acquisition Cost by Channel")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #Conversion rate by Channel

# %%
data.head()
# Out:
#    customer_id           channel       cost  conversion_rate  revenue
# 0            1          referral   8.320327         0.123145     4199
# 1            2  paid advertising  30.450327         0.016341     3410
# 2            3   email marketing   5.246263         0.043822     3164
# 3            4      social media   9.546326         0.167592     1520
# 4            5          referral   8.320327         0.123145     2419

# %%
conversion_by_channel = data.groupby("channel")["conversion_rate"].mean().reset_index()

# %%
conversion_by_channel
# Out:
#             channel  conversion_rate
# 0   email marketing         0.043822
# 1  paid advertising         0.016341
# 2          referral         0.123145
# 3      social media         0.167592

# %%
conversion_by_channel = data.groupby("channel")["conversion_rate"].mean().reset_index()

fig = px.bar(conversion_by_channel,
             x="channel", y="conversion_rate",
             title="Conversion Rate by Channel")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #Total revenue by channel

# %%
revenue_by_channel = data.groupby('channel')['revenue'].sum().reset_index()

fig = px.pie(revenue_by_channel,
             values="revenue", names="channel",
             title="Total revenue by Channel",
             hole=0.6, color_discrete_sequence=px.colors.qualitative.Pastel)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #Return on Investment for each channel

# %%
data['roi'] = (data['revenue']) / data['cost']
roi_by_channel = data.groupby('channel')['roi'].mean().reset_index()

fig = px.bar(roi_by_channel,
             x="channel", y="roi",
             title="Return on Investment by Channel")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
